# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as py

# %%
df = pd.read_csv('data_science_asia_clean.csv',index_col=0)

# %%
df.head(10)
# Out:
#     Duration What is your age (# years)? What is your gender?  \
# 1        470                       55-59                  Man
# 2        174                       25-29                Woman
# 3        506                       25-29                  Man
# 4        283                       22-24                Woman
# 5        492                       40-44                  Man
# 6        985                       30-34                  Man
# 7        299                       25-29                  Man
# 8        512                       40-44                  Man
# 9        380                       18-21                  Man
# 10       268                       18-21            Nonbinary
#
#    In which country do you currently reside? Are you currently a student?  \
# 1                                South Korea                           No
# 2                                      China                          Yes
# 3                                      Japan                           No
# 4                                      China                          Yes
# 5                                      Japan                           No
# 6                                      Japan                           No
# 7                                South Korea                          Yes
# 8                                   Viet Nam                          Yes
# 9                                   Viet Nam                          Yes
# 10                                     China                          Yes
#
#    On which platforms have you begun or completed data science courses?  \
# 1   ('University Courses (resulting in a universit...
# 2   ('Kaggle Learn Courses', 'University Courses (...
# 3                                          ('Udemy',)
# 4   ('University Courses (resulting in a universit...
# 5                           ('Kaggle Learn Courses',)
# 6   ('University Courses (resulting in a universit...
# 7   ('University Courses (resulting in a universit...
# 8   ('Cloud-certification programs (direct from AW...
# 9                                           ('None',)
# 10  ('Coursera', 'University Courses (resulting in...
#
#    What products or platforms did you find to be most helpful when you first started studying data science?  \
# 1          ('Kaggle (notebooks, competitions, etc)',)
# 2   ('University courses', 'Online courses (Course...
# 3            ('Online courses (Coursera, EdX, etc)',)
# 4   ('University courses', 'Social media platforms...
# 5   ('Video platforms (YouTube, Twitch, etc)', 'Ka...
# 6   ('University courses', 'Kaggle (notebooks, com...
# 7   ('University courses', 'Video platforms (YouTu...
# 8   ('University courses', 'Kaggle (notebooks, com...
# 9   ('University courses', 'Online courses (Course...
# 10  ('Social media platforms (Reddit, Twitter, etc...
#
#    What is the highest level of formal education that you have attained or plan to attain within the next 2 years?  \
# 1                                     Master’s degree
# 2                                     Master’s degree
# 3                                     Master’s degree
# 4                              I prefer not to answer
# 5                No formal education past high school
# 6                                     Master’s degree
# 7                                     Master’s degree
# 8                                     Doctoral degree
# 9   Some college/university study without earning ...
# 10                                  Bachelor’s degree
#
#    For how many years have you been writing code and/or programming?  \
# 1                                           1-3 years
# 2                                           < 1 years
# 3                                           3-5 years
# 4                                           < 1 years
# 5                                           < 1 years
# 6                                          5-10 years
# 7                                           1-3 years
# 8                                         10-20 years
# 9                                           < 1 years
# 10                                          1-3 years
#
#    What programming languages do you use on a regular basis?  \
# 1                                   ('Python', 'SQL')
# 2                                ('Python', 'MATLAB')
# 3                                         ('Python',)
# 4                       ('Python', 'MATLAB', 'Other')
# 5                                         ('Python',)
# 6   ('Python', 'R', 'SQL', 'Java', 'Javascript', '...
# 7                                     ('Python', 'R')
# 8   ('Python', 'SQL', 'C#', 'C++', 'Javascript', '...
# 9                                   ('Python', 'SQL')
# 10                             ('Python', 'R', 'SQL')
#
#    Which of the following integrated development environments (IDE's) do you use on a regular basis?  \
# 1                  (' PyCharm ', ' Jupyter Notebook')
# 2   (' Visual Studio ', ' MATLAB ', ' Jupyter Note...
# 3   (' Visual Studio Code (VSCode) ', ' Jupyter No...
# 4        (' Visual Studio ', ' PyCharm ', ' MATLAB ')
# 5              ('  Notepad++  ', ' Jupyter Notebook')
# 6   ('JupyterLab ', ' RStudio ', ' Visual Studio '...
# 7   (' Visual Studio ', ' PyCharm ', ' Jupyter Not...
# 8   ('JupyterLab ', ' Visual Studio ', ' Visual St...
# 9   (' Visual Studio Code (VSCode) ', ' PyCharm ',...
# 10                 (' RStudio ', ' Jupyter Notebook')
#
#    Do you use any of the following hosted notebook products?  \
# 1                                           ('None',)
# 2   ('Colab Notebooks', 'Google Cloud Vertex AI Wo...
# 3            (' Kaggle Notebooks', 'Colab Notebooks')
# 4              ('Google Cloud Vertex AI Workbench ',)
# 5                                           ('None',)
# 6   ('Colab Notebooks', ' Amazon Sagemaker Studio ...
# 7            (' Kaggle Notebooks', 'Colab Notebooks')
# 8   (' Kaggle Notebooks', 'Colab Notebooks', 'Azur...
# 9                                           ('None',)
# 10                                          ('None',)
#
#    Do you use any of the following data visualization libraries on a regular basis?  \
# 1                       (' Matplotlib ', ' Seaborn ')
# 2                                                 NaN
# 3                                      (' Seaborn ',)
# 4                                           ('None',)
# 5                                           ('None',)
# 6                       (' Matplotlib ', ' Seaborn ')
# 7                       (' Matplotlib ', ' Seaborn ')
# 8   (' Matplotlib ', ' Ggplot / ggplot2 ', ' Geopl...
# 9                       (' Matplotlib ', ' Seaborn ')
# 10             (' Matplotlib ', ' Ggplot / ggplot2 ')
#
#    For how many years have you used machine learning methods?  \
# 1                                           1-2 years
# 2                                                 NaN
# 3                                           2-3 years
# 4                                        Under 1 year
# 5               I do not use machine learning methods
# 6                                           3-4 years
# 7                                           1-2 years
# 8                                          5-10 years
# 9               I do not use machine learning methods
# 10                                          1-2 years
#
#    Which of the following machine learning frameworks do you use on a regular basis?  \
# 1                                ('  Scikit-learn ',)
# 2                                                 NaN
# 3   ('  Scikit-learn ', ' PyTorch ', ' Xgboost ', ...
# 4                                  ('  TensorFlow ',)
# 5                                                 NaN
# 6   ('  Scikit-learn ', ' Keras ', ' PyTorch ', ' ...
# 7   ('  TensorFlow ', ' Keras ', ' Xgboost ', ' Li...
# 8   ('  Scikit-learn ', '  TensorFlow ', ' Keras '...
# 9                                                 NaN
# 10                               ('  Scikit-learn ',)
#
#    Which of the following ML algorithms do you use on a regular basis?  \
# 1   ('Linear or Logistic Regression', 'Decision Tr...
# 2                                                 NaN
# 3   ('Decision Trees or Random Forests', 'Dense Ne...
# 4                                           ('None',)
# 5                                                 NaN
# 6   ('Linear or Logistic Regression', 'Decision Tr...
# 7   ('Decision Trees or Random Forests', 'Gradient...
# 8   ('Linear or Logistic Regression', 'Decision Tr...
# 9                                                 NaN
# 10                 ('Linear or Logistic Regression',)
#
#    Do you download pre-trained model weights from any of the following services?  \
# 1   ('No, I do not download pre-trained model weig...
# 2                                                 NaN
# 3                           (' Huggingface Models ',)
# 4     ('Other storage services (i.e. google drive)',)
# 5                                                 NaN
# 6   (' PyTorch Hub ', ' Huggingface Models ', ' Ti...
# 7   ('No, I do not download pre-trained model weig...
# 8   ('  TensorFlow Hub ', ' PyTorch Hub ', ' NVIDI...
# 9                                                 NaN
# 10  ('No, I do not download pre-trained model weig...
#
#    Who/what are your favorite media sources that report on data science topics?
# 1                                                 NaN
# 2                                                 NaN
# 3                ('Kaggle (notebooks, forums, etc)',)
# 4                                          ('Other',)
# 5                ('Kaggle (notebooks, forums, etc)',)
# 6   ('Twitter (data science influencers)', "Email ...
# 7   ('Kaggle (notebooks, forums, etc)', 'YouTube (...
# 8   ('Kaggle (notebooks, forums, etc)', 'Course Fo...
# 9   ('Kaggle (notebooks, forums, etc)', 'YouTube (...
# 10  ('Blogs (Towards Data Science, Analytics Vidhy...

# %%
df.columns
# Out:
# Index(['Duration', 'What is your age (# years)?', 'What is your gender?',
#        'In which country do you currently reside?',
#        'Are you currently a student?',
#        'On which platforms have you begun or completed data science courses?',
#        'What products or platforms did you find to be most helpful when you first started studying data science?',
#        'What is the highest level of formal education that you have attained or plan to attain within the next 2 years?',
#        'For how many years have you been writing code and/or programming?',
#        'What programming languages do you use on a regular basis?',
#        'Which of the following integrated development environments (IDE's) do you use on a regular basis?',
#        'Do you use any of the following hosted notebook products?',
#        'Do you use any of the following data visualization libraries on a regular basis?',
#        'For how many years have you used machine learning methods?',
#        'Which of the following machine learning frameworks do you use on a regular basis?',
#        'Which of the following ML algorithms do you use on a regular basis?',
#        'Do you download pre-trained model weights from any of the following services?',
#        'Who/what are your favorite media sources that report on data science topics?'],
#       dtype='object')

# %%
age = 'What is your age (# years)?'
gender = 'What is your gender'
country = 'In which country do you currently reside?'
education = 'What is the highest level of formal education that you have attained or plan to attain within the next 2 years?'

# %% [markdown]
# Vẽ phân phối tuổi

# %%
def age_distribute(ax, country,data):
    data_age = df[age].value_counts().sort_index()
    ax.bar(data.index, data, width=0.55, 
       edgecolor='darkgray', color='#d4dddd',
       linewidth=0.7)
    ax.set_title('Age Distribution of {}'.format(country))
    ax.grid(axis='y', linestyle='-', alpha=0.5)

# %%
age_country = df.groupby([country,age])[age].count()

# %%
fig, ax = plt.subplots(2,2, figsize=(15, 10))
ax_flat = ax.flatten()
age_distribute(ax_flat[0],'China',age_country.loc['China'])
age_distribute(ax_flat[1],'Viet Nam',age_country.loc['Viet Nam'])
age_distribute(ax_flat[2],'South Korea',age_country.loc['South Korea'])
age_distribute(ax_flat[3],'Japan',age_country.loc['Japan'])
plt.show()

# %% [markdown]
# - Ta nhận thấy ở Việt Nam và Trung Quốc thì số lượng lao động trẻ rất cao (từ 18 - 24), trong khi đó số lượng lao động có kinh nghiệm với giảm nhanh và ít hơn rất nhiều. Điều này chứng tỏ đây là 2 thị trường khá là mới và tiềm năng của ngành này. Tuy nhiên ở thị trường Việt Nam thì số lượng lao động có kinh nghiệm lại ít hơn khá nhiều nên lo sợ việc chất lượng lao động được đào tạo bài bản không cao.
# - Ở Hàn và Nhật thì lại trái ngược lại khi số lượng lao động có kinh nghiệm lại nhiều hơn số lượng lao động trẻ, có thể là do xu hướng già hoá dân số ở hai nước này và có vẻ như ngành DS đã qua thời kì hot ở hai nước này. Tuy nhiên số lượng lao động có kinh nghiệm của họ lại rất nhiều, cho thấy rằng chất lượng nhân sự của họ rất tốt, đây sẽ là hai thị trường tuy không còn hot nhưng chất lượng lại vô cùng tốt.

# %%
edu = df.groupby([country,education])[education].count()
edu
# Out:
# In which country do you currently reside?  What is the highest level of formal education that you have attained or plan to attain within the next 2 years?
# China                                      Bachelor’s degree                                                                                                   93
#                                            Doctoral degree                                                                                                     53
#                                            I prefer not to answer                                                                                              38
#                                            Master’s degree                                                                                                    187
#                                            No formal education past high school                                                                                15
#                                            Professional doctorate                                                                                               6
#                                            Some college/university study without earning a bachelor’s degree                                                   41
# Japan                                      Bachelor’s degree                                                                                                  110
#                                            Doctoral degree                                                                                                     65
#                                            I prefer not to answer                                                                                              66
#                                            Master’s degree                                                                                                    191
#                                            No formal education past high school                                                                                66
#                                            Professional doctorate                                                                                               9
#                                            Some college/university study without earning a bachelor’s degree                                                   27
# South Korea                                Bachelor’s degree                                                                                                   72
#                                            Doctoral degree                                                                                                     52
#                                            I prefer not to answer                                                                                              34
#                                            Master’s degree                                                                                                     86
#                                            No formal education past high school                                                                                16
#                                            Professional doctorate                                                                                              12
#                                            Some college/university study without earning a bachelor’s degree                                                   30
# Viet Nam                                   Bachelor’s degree                                                                                                   65
#                                            Doctoral degree                                                                                                     10
#                                            I prefer not to answer                                                                                              23
#                                            Master’s degree                                                                                                     66
#                                            No formal education past high school                                                                                 7
#                                            Professional doctorate                                                                                               8
#                                            Some college/university study without earning a bachelor’s degree                                                   24
# Name: What is the highest level of formal education that you have attained or plan to attain within the next 2 years?, dtype: int64

# %%
def pie_pro(ax, country,data):
    sns.set_style("whitegrid")  # Đặt phong cách
    custom_colors = sns.color_palette("Set3", len(data))
    ax.pie(data.values, colors=custom_colors, autopct='%1.1f%%', startangle=90)
    plt.axis('equal')
    ax.set_title('Age Distribution of {}'.format(country))

# %%
fig, ax = plt.subplots(2,2, figsize=(10, 10))
ax_flat = ax.flatten()
pie_pro(ax_flat[0],'China',edu.loc['China'])
pie_pro(ax_flat[1],'Viet Nam',edu.loc['Viet Nam'])
pie_pro(ax_flat[2],'South Korea',edu.loc['South Korea'])
pie_pro(ax_flat[3],'Japan',edu.loc['Japan'])
plt.legend(edu.loc['China'].index,bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# - Ta nhận thấy rằng dù ở nước nào thì bằng Master đều chiếm phần lớn nhất, chứng tỏ rằng bằng Master là vô cùng quan trọng ở ngành DS. Tuy nhiên bằng tiến sĩ hay giáo sư lại ít hơn nhiều. Chứng tỏ bằng Master là để cho yêu cầu làm việc chứ không nhiều người muốn đi theo hướng nghiên cứu. Nhưng điều này cũng khẳng định rằng nếu bạn muốn làm trong ngành này thì yêu cầu về kiến thức là vô cùng cao.
# - Ở Nhật Bản thì tỷ lệ người không học đại học nhưng ra làm ngành này là nhiều hơn hẳn so với 3 nước còn lại. Có thể ở thị trường Nhật Bản thì yêu cầu bằng cấp là không nhiều. Tuy nhiên tỷ lệ bằng Master cao chứng tỏ rằng nếu muốn có một công việc chắc ăn thì bạn cần học ở các cơ sở đào tạo chính quy
